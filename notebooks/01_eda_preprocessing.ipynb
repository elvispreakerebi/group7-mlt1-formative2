# %% [markdown]
# # 01 EDA and Preprocessing
#
# This notebook summarizes the data understanding and preprocessing evidence. The reusable work lives in `src/`; the notebook calls the same scripts used for reproducibility.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

print(f"Python: {sys.executable}")

from src.utils import load_config
from src.data import load_dataset, dataset_summary

config = load_config(ROOT / 'config.yaml')
bundle = load_dataset(config)
dataset_summary(bundle, config)
# Out:
#    train_rows  test_rows  train_columns  test_columns  unique_labels  \
# 0        2995        998             15             3             27
#
#    missing_train_text  missing_test_text  unique_train_types  \
# 0                   0                  0                   8
#
#    unique_test_types  mean_labels_per_row  max_labels_per_row
# 0                  8               1.9703                  10

# %%
import os
import subprocess
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
venv_python = ROOT / '.venv' / 'bin' / 'python'
script = ROOT / 'scripts' / 'run_eda.py'
runner = venv_python if venv_python.exists() else Path(sys.executable)

env = os.environ.copy()
if venv_python.exists():
    env['MPLCONFIGDIR'] = str(ROOT / 'cache' / 'matplotlib')

completed = subprocess.run(
    [str(runner), str(script)],
    cwd=ROOT,
    check=True,
    text=True,
    capture_output=True,
    env=env,
)
print(completed.stdout, end='')
if completed.stderr:
    print(completed.stderr, end='')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/ALU/group7-mlt1-formative2/scripts/run_eda.py:91
#      87     print(f"EDA outputs written to {resolve_path(tables_dir)} and {resolve_path(figures_dir)}")
#      90 if __name__ == "__main__":
# ---> 91     main()
#
# File ~/Documents/ALU/group7-mlt1-formative2/scripts/run_eda.py:52, in main()
#      49 cooccurrence = pd.DataFrame(bundle.labels.T.dot(bundle.labels), index=bundle.label_names, columns=bundle.label_names)
#      50 save_table(cooccurrence.reset_index(names="label"), f"{tables_dir}/label_cooccurrence.csv")
# ---> 52 save_barplot(
#      53     label_frequency.head(15),
#      54     x="label",
#      55     y="count",
#      56     title="Top 15 SDG 3 Indicator Labels",
#      57     path=f"{figures_dir}/label_frequency.png",
#      58 )
#      59 save_barplot(
#      60     label_cardinality,
# ...

# %% [markdown]
# Key generated outputs are in `reports/tables/` and `reports/figures/`. These include label frequency, label cardinality, source type distribution, text length, and label co-occurrence.
